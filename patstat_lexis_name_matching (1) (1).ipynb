# %%
# %%capture
# !pip install name-matching awswrangler ray

# %%
import pandas as pd
from name_matching.name_matcher import NameMatcher
import awswrangler as wr
import ray
import numpy as np

# %%
patstat_names_query = """SELECT distinct(trim(replace(psn_name, '"', ''))) as firm_name, 
                                trim(replace(person_ctry_code, '"', '')) as country_code
                      from tls206_person 
                      where psn_sector='"COMPANY"'
                      or han_name='"COMPANY"'
                      """
df = wr.athena.read_sql_query(patstat_names_query, database="patstat-global-spring-2021")

# %%
df
# Out:
#                                                  firm_name country_code
# 0           ZHEJIANG YUELONG LANDSCAPE CONSTRUCTION CO LTD         LTD.
# 1                                               FOUR FLAGS           AU
# 2                    SHANXI LONGZHI ENERGY CHEMICAL CO LTD         LTD.
# 3                                BELL FLAVORS & FRAGRANCES           DE
# 4                   YANGZHOU HERUI PREC MANUFACTURE CO LTD         LTD.
# ...                                                    ...          ...
# 4900288                           FA AG EISENHUTTE PRINZ R
# 4900289             ENSINK NV MASCHINEFAB EN IJZERGIETERIJ
# 4900290                     BRITISH IRON AND STEEL RES ASS
# 4900291  PERET A CO FOR PLANNING AND DEV OF IDEAS FOR I...
# 4900292                       KOORNFONTEIN KOOLMYNE BEPERK
#
# [4900293 rows x 2 columns]

# %%
country_counts = df[df.country_code.str.len()==2].country_code.value_counts()
country_counts.head(30)
# Out:
# US    202764
# DE    184328
# GB     77433
# IT     75953
# FR     74996
# CN     57344
# JP     41694
# CH     40936
# SE     36237
# CA     34560
# KR     31944
# RU     30193
# NL     27933
# AU     27215
# BR     24168
# SU     24058
# TW     19440
# AT     15519
# PL     14787
# DK     13870
# TR     13035
# IL     12757
# FI     12672
# ES     12137
# NO     10583
# BE      9868
# DD      8006
# HU      7240
# HK      6479
# CZ      5526
# Name: country_code, dtype: Int64

# %%
num_patstat_firms_with_country_code = country_counts.sum()
print(f'Share of Patstat firms with a valid country code: {num_patstat_firms_with_country_code/len(df):.2f}')
# Out:
# Share of Patstat firms with a valid country code: 0.25

# %%
orbis_lexis = pd.read_csv('s3://alliance-network/lexis_alliances_orbis_static.csv')
r_and_d = pd.read_csv('s3://alliance-network/ResearchandDevelopment_LexisNexis.csv')

# %%
r_and_d_firm_ids = set(r_and_d['firm_a'].unique()) | set(r_and_d['firm_b'].unique())
orbis_lexis = orbis_lexis[orbis_lexis['BvD ID number'].isin(r_and_d_firm_ids)]

# %%
orbis_lexis
# Out:
#                    Company name Latin alphabet BvD ID number Country ISO code  \
# 0               AMERICAN UNIVERSITY OF SHARJAH  AE0000025189               AE
# 1                   CRESCENT PETROLEUM COMPANY  AE0000037027               AE
# 32                              ALPHA DATA LLC  AE0000039967               AE
# 58      ABU DHABI NATIONAL OIL COMPANY (ADNOC)  AE0000047504               AE
# 65         JUMBO ELECTRONICS CO. LTD. (L.L.C.)  AE0000048486               AE
# ...                                        ...           ...              ...
# 165905               DELTA CORPORATION LIMITED     ZW30009KZ               ZW
# 165910                TURNALL HOLDINGS LIMITED     ZW30039KZ               ZW
# 165911                    CFI HOLDINGS LIMITED     ZW30047KZ               ZW
# 165920                AXIA CORPORATION LIMITED     ZW30092KZ               ZW
# 165928                     TA HOLDINGS LIMITED  ZWFEI1014449               ZW
#
#        City\nLatin Alphabet  NACE Rev. 2, core code (4 digits)  \
# 0                   SHARJAH                             8541.0
# 1                   SHARJAH                             7112.0
# 32                ABU DHABI                             4652.0
# 58                ABU DHABI                              610.0
# 65                    DUBAI                             4669.0
# ...                     ...                                ...
# 165905       HARARE, HARARE                             1107.0
# 165910       HARARE, HARARE                             3522.0
# 165911       HARARE, HARARE                             6420.0
# 165920               HARARE                             7022.0
# 165928               HARARE                             6499.0
#
#         NACE Rev. 2, secondary code(s)
# 0                               8542.0
# 1                                  NaN
# 32                              4778.0
# 58                              7112.0
# 65                              6202.0
# ...                                ...
# 165905                             NaN
# 165910                             NaN
# 165911                             NaN
# 165920                             NaN
# 165928                          6420.0
#
# [15103 rows x 6 columns]

# %%
# ## add country codes to name match column
# df['firm_name_match'] = df.firm_name.str.strip() + ' ' + df.country_code.str.strip()
# orbis_lexis['firm_name_match'] = orbis_lexis['Company name Latin alphabet'].str.strip() + ' ' + orbis_lexis['Country ISO code'].str.strip()

# %%
ray.init()
# Out:
# 2023-03-24 13:15:33,864	INFO worker.py:1553 -- Started a local Ray instance.
# RayContext(dashboard_url='', python_version='3.10.8', ray_version='2.3.0', ray_commit='cf7a56b4b0b648c324722df7c99c168e92ff0b45', address_info={'node_ip_address': '172.16.33.83', 'raylet_ip_address': '172.16.33.83', 'redis_address': None, 'object_store_address': '/tmp/ray/session_2023-03-24_13-15-32_089913_11798/sockets/plasma_store', 'raylet_socket_name': '/tmp/ray/session_2023-03-24_13-15-32_089913_11798/sockets/raylet', 'webui_url': '', 'session_dir': '/tmp/ray/session_2023-03-24_13-15-32_089913_11798', 'metrics_export_port': 40195, 'gcs_address': '172.16.33.83:52558', 'address': '172.16.33.83:52558', 'dashboard_agent_listen_port': 52365, 'node_id': '3e00da76c32269f10ff4642953be55f9878efec68f80ef4b8753923d'})

# %%
cpu_count = ray.nodes()[0]['Resources']['CPU']
cpu_count
# Out:
# 36.0

# %%
def split_df(df, chunk_size):
    num_chunks = len(df) // chunk_size + 1
    return np.array_split(df, num_chunks)

@ray.remote
def match_names(df, column_matching):
    matcher = NameMatcher(low_memory=False, top_n=5, common_words=False, legal_suffixes=True,
                          distance_metrics=['editex', 'discounted_levenshtein',
                                            'refined_soundex'],
                         verbose=True)
    matcher.load_and_process_master_data('Company name Latin alphabet', orbis_lexis)
    res = matcher.match_names(to_be_matched=df, column_matching=column_matching)
    matches = res[res.score > 95]
    return matches

def match_names_multiprocessing(df, column_matching, chunk_size=10000):
    df_batches = split_df(df, chunk_size)
    futures = [match_names.remote(df, column_matching) for df in df_batches]
    matches = ray.get(futures)
    return pd.concat(matches)

# %%
matches = match_names_multiprocessing(df, 'firm_name', chunk_size=len(df)//cpu_count+1)
# Out:
# (match_names pid=13449) done
# 100%|██████████| 136119/136119 [37:24<00:00, 60.64it/s]

# %%
matches.to_pickle('matches.pkl')

# %%
matches
# Out:
#                               original_name  \
# 105                              embrex inc
# 117                   volvo technology corp
# 313                             aisin seiki
# 555          ortho clinical diagnostics inc
# 646                            robert bosch
# ...                                     ...
# 4899397                  tokyo electron ltd
# 4899747              top victory investment
# 4899777                         artemis ood
# 4900048                          pfenex inc
# 4900162  claas selbstfahrende ernemaschinen
#
#                                        match_name       score  match_index
# 105                                        embrex  100.000000       8657.0
# 117                           volvo technology ab  100.000000       6918.0
# 313                   aisin seiki company limited  100.000000       3538.0
# 555                 orthoclinical diagnostics inc   97.188593      11537.0
# 646                              robert bosch srl  100.000000       6378.0
# ...                                           ...         ...          ...
# 4899397                    tokyo electron limited  100.000000       5184.0
# 4899747           top victory investments limited   95.172938       3905.0
# 4899777                                   artemis  100.000000       2673.0
# 4900048                                pfenex inc  100.000000      13892.0
# 4900162  claas selbstfahrende erntemaschinen gmbh   96.467817       1904.0
#
# [43292 rows x 4 columns]

# %%
merge_matches = matches.reset_index(names='df_index')[['match_index', 'df_index']]
merged = orbis_lexis.reset_index(drop=True).merge(merge_matches, left_index=True, right_on='match_index')
merged = merged.merge(df, left_on='df_index', right_index=True).drop(columns=['match_index', 'df_index'])

# %%
merged
# Out:
#                   Company name Latin alphabet BvD ID number Country ISO code  \
# 9077                           ALPHA DATA LLC  AE0000039967               AE
# 43264                          ALPHA DATA LLC  AE0000039967               AE
# 15767  ABU DHABI NATIONAL OIL COMPANY (ADNOC)  AE0000047504               AE
# 2685              SANY HEAVY INDUSTRY CO. LTD  AE0000588591               AE
# 9402              SANY HEAVY INDUSTRY CO. LTD  AE0000588591               AE
# ...                                       ...           ...              ...
# 2555                         TRIANGLE LIMITED  ZW0000033705               ZW
# 16940                        TRIANGLE LIMITED  ZW0000033705               ZW
# 22258                        TRIANGLE LIMITED  ZW0000033705               ZW
# 29507                        TRIANGLE LIMITED  ZW0000033705               ZW
# 38189                        TRIANGLE LIMITED  ZW0000033705               ZW
#
#       City\nLatin Alphabet  NACE Rev. 2, core code (4 digits)  \
# 9077             ABU DHABI                             4652.0
# 43264            ABU DHABI                             4652.0
# 15767            ABU DHABI                              610.0
# 2685                 DUBAI                             4752.0
# 9402                 DUBAI                             4752.0
# ...                    ...                                ...
# 2555              TRIANGLE                             1081.0
# 16940             TRIANGLE                             1081.0
# 22258             TRIANGLE                             1081.0
# 29507             TRIANGLE                             1081.0
# 38189             TRIANGLE                             1081.0
#
#        NACE Rev. 2, secondary code(s)  \
# 9077                           4778.0
# 43264                          4778.0
# 15767                          7112.0
# 2685                              NaN
# 9402                              NaN
# ...                               ...
# 2555                              NaN
# 16940                             NaN
# 22258                             NaN
# 29507                             NaN
# 38189                             NaN
#
#                                                firm_name country_code
# 9077                                          ALPHA DATA
# 43264                                         ALPHA DATA           JP
# 15767             ABU DHABI NATIONAL OIL COMPANY (ADNOC)           AE
# 2685                         SANY HEAVY INDUSTRY COMPANY
# 9402   サニー ヘビー インダストリー カンパニー リミテッドＳＡＮＹ ＨＥＡＶＹ ＩＮＤＵＳＴＲＹ...
# ...                                                  ...          ...
# 2555                                            TRIANGLE           DE
# 16940                                           TRIANGLE
# 22258                                           TRIANGLE           FR
# 29507                                    TRIANGLE CO LTD         LTD.
# 38189                                           TRIANGLE           US
#
# [43292 rows x 8 columns]

# %%
merged.to_parquet('patstat-orbis-name-matches.parquet')

# %%
name_orbis_correspondence = merged.drop_duplicates('firm_name')[['BvD ID number', 'firm_name']]
name_orbis_correspondence.columns = ['bvdid', 'firm_name']
name_orbis_correspondence.to_parquet('patstat-orbis-name-bvdid-correspondence.parquet')

# %%
df.to_parquet('patstat-orbis-originial-df.parquet')
