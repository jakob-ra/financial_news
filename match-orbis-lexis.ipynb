# %%
# !pip install -qU awswrangler name_matching ray swifter

# %%
import awswrangler as wr
import pandas as pd
import swifter
import re
import unidecode
import numpy as np
import os
import glob

# %% [markdown]
# # Financials

# %%
sql = """SELECT bvdid, closing_date, total_assets, capital, number_of_employees, operating_revenue_turnover, 
sales, gross_profit, added_value, research_and_development_expenses FROM global_financials_and_ratios"""
financials = wr.athena.read_sql_query(sql, database="orbiskof2023")
financials
# Out:
#                      bvdid  closing_date  total_assets   capital
# 0            AU60820328151          2015           NaN       NaN  \
# 1            AU60820328151          2014           NaN       NaN
# 2            AU60820328151          2013           NaN       NaN
# 3              AU608203327          2015           NaN       NaN
# 4              AU608203336          2015           NaN       NaN
# ...                    ...           ...           ...       ...
# 602960124  TH0105535169128      20161231        1368.0  242613.0
# 602960125  TH0105535169128      20151231         887.0  230461.0
# 602960126  TH0105535169128      20141231        2882.0  237569.0
# 602960127  TH0105535169128      20131231        3017.0  218172.0
# 602960128  TH0105535169128      20121231           NaN  216835.0
#
#            number_of_employees  operating_revenue_turnover     sales
# 0                          NaN                         3.0  730600.0  \
# 1                          NaN                         3.0  820200.0
# 2                          NaN                         3.0       NaN
# 3                          NaN                         3.0       NaN
# 4                          NaN                         3.0       NaN
# ...                        ...                         ...       ...
# 602960124                  NaN                         NaN  113227.0
# 602960125                  NaN                         NaN  109370.0
# 602960126                  NaN                         NaN  121257.0
# 602960127                  NaN                         NaN  117025.0
# 602960128                  NaN                         NaN  115795.0
#
#            gross_profit  added_value  research_and_development_expenses
# 0                   NaN          NaN                                NaN
# 1                   NaN          NaN                                NaN
# 2                   NaN          NaN                                NaN
# 3                   NaN          NaN                                NaN
# 4                   NaN          NaN                                NaN
# ...                 ...          ...                                ...
# 602960124           NaN          NaN                                NaN
# 602960125           NaN      13467.0                                NaN
# 602960126           NaN      20478.0                                NaN
# 602960127           NaN      15969.0                                NaN
# 602960128           NaN          NaN                                NaN
#
# [602960129 rows x 10 columns]

# %%
financials.memory_usage(index=False, deep=True)/1e9
# Out:
# bvdid                                41.454362
# closing_date                          3.014801
# total_assets                          2.411841
# capital                               2.411841
# number_of_employees                   2.411841
# operating_revenue_turnover            2.411841
# sales                                 2.411841
# gross_profit                          2.411841
# added_value                           2.411841
# research_and_development_expenses     2.411841
# dtype: float64

# %%
financials.isna().sum()/len(financials)*100
# Out:
# bvdid                                 0.000000
# closing_date                          0.000000
# total_assets                         59.168658
# capital                              45.562211
# number_of_employees                  99.788665
# operating_revenue_turnover           43.169468
# sales                                39.406028
# gross_profit                         87.838708
# added_value                          79.421020
# research_and_development_expenses    85.127186
# dtype: float64

# %%
df = financials[(financials.number_of_employees >= 100) | (financials.operating_revenue_turnover > 10000) | (financials.sales > 10000000)]

# %%
financials

# %% [markdown]
# # Key financials

# %%
sql = """SELECT bvdid, closing_date, total_assets, number_of_employees, operating_revenue_turnover, market_capitalisation_mil FROM key_financials"""
key_financials = wr.athena.read_sql_query(sql, database="orbiskof2023")
key_financials
# Out:
#                 bvdid  closing_date  total_assets  number_of_employees
# 0          UA42012013      20181231          3525                 <NA>  \
# 1          UA40918617      20201231         22416                    2
# 2          UA40918617      20191231            84                    2
# 3          UA40918617      20181231          8765                   20
# 4          UA40918617      20171231         34987                   15
# ...               ...           ...           ...                  ...
# 467951975  NL69724687      20201231      18538890                 <NA>
# 467951976  NL69724687      20191231      17496394                 <NA>
# 467951977  NL69724687      20181231      20433913                 <NA>
# 467951978  NL69724687      20171231        179895                 <NA>
# 467951979  NL69724660      20211231        641774                 <NA>
#
#            operating_revenue_turnover  market_capitalisation_mil
# 0                                <NA>                       <NA>
# 1                               26752                       <NA>
# 2                                <NA>                       <NA>
# 3                                <NA>                       <NA>
# 4                               48701                       <NA>
# ...                               ...                        ...
# 467951975                        <NA>                       <NA>
# 467951976                        <NA>                       <NA>
# 467951977                        <NA>                       <NA>
# 467951978                        <NA>                       <NA>
# 467951979                        <NA>                       <NA>
#
# [467951980 rows x 6 columns]

# %%
key_financials.memory_usage(index=False, deep=True)/1e9
# Out:
# bvdid                         32.274981
# closing_date                   2.339760
# total_assets                   4.211568
# number_of_employees            2.339760
# operating_revenue_turnover     4.211568
# market_capitalisation_mil      2.339760
# dtype: float64

# %%
key_financials.isna().sum()/len(key_financials)*100
# Out:
# bvdid                          0.000000
# closing_date                   0.000000
# total_assets                  43.599474
# number_of_employees           34.141406
# operating_revenue_turnover    31.734922
# market_capitalisation_mil     99.822700
# dtype: float64

# %%
key_financials.operating_revenue_turnover.describe()
# Out:
# count           319447784.0
# mean         19596354.57702
# std      79921933355.030823
# min        -1685702883376.0
# 25%                 22445.0
# 50%                177717.0
# 75%                719312.0
# max      1251616149443280.0
# Name: operating_revenue_turnover, dtype: Float64

# %%
key_financials.market_capitalisation_mil.describe()
# Out:
# count       829679.0
# mean     1698.025295
# std      13813.97961
# min              0.0
# 25%             32.0
# 50%            129.0
# 75%            577.0
# max        2417523.0
# Name: market_capitalisation_mil, dtype: Float64

# %%
key_financials[key_financials.number_of_employees >= 100].bvdid.nunique()
# Out:
# 1797476

# %%
key_financials[(key_financials.operating_revenue_turnover > 10000000)].bvdid.nunique()
# Out:
# 3641800

# %%
df = key_financials[(key_financials.number_of_employees >= 100) | (key_financials.operating_revenue_turnover > 10000000) | (key_financials.market_capitalisation_mil > 0)]
df = df.sort_values(['bvdid', 'closing_date'], ascending=True).copy(deep=True)
# Out:
# /tmp/ipykernel_10216/1756731600.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.sort_values('operating_revenue_turnover', inplace=True)

# %%
df = df.sort_values(['bvdid', 'closing_date'], ascending=True).copy(deep=True)

# %%
df.bvdid.nunique()
# Out:
# 4495886

# %%
df.sort_values('number_of_employees', ascending=False).head(30)
# Out:
#                   bvdid  closing_date   total_assets  number_of_employees
# 344438669  US142591828L          2021           <NA>              2700000  \
# 344446988   US710415188      20160131   199581000000              2300000
# 344446987   US710415188      20170131   198825000000              2300000
# 344446986   US710415188      20180131   204522000000              2300000
# 344446982   US710415188      20220131   244860000000              2300000
# 344446983   US710415188      20210131   252496000000              2300000
# 344446985   US710415188      20190131   219295000000              2200000
# 344446992   US710415188      20120131   193406000000              2200000
# 344446991   US710415188      20130131   203105000000              2200000
# 344446990   US710415188      20140131   204751000000              2200000
# 344446989   US710415188      20150131   203490000000              2200000
# 344446984   US710415188      20200131   236495000000              2200000
# 344446994   US710415188      20100131   170407000000              2100000
# 344446995   US710415188      20090131   163429000000              2100000
# 344446993   US710415188      20110131   180782000000              2100000
# 344446996   US710415188      20080131   163514000000              2100000
# 344447910  CN9398811502      20181231  1167713298682              2058600
# 344447909  CN9398811502      20191231  1190061950400              1987000
# 344446997   US710415188      20070131   151587000000              1900000
# 344446998   US710415188      20060131   138187000000              1800000
# 344446999   US710415188      20050131   120154000000              1700000
# 344447012   US911646860      20211231   420549000000              1608000
# 344447000   US710415188      20040131   105405000000              1500000
# 344447001   US710415188      20030131    94808000000              1400000
# 344447002   US710415188      20020131    83527000000              1383000
# 344447013   US911646860      20201231   321195000000              1298000
# 344447110  CN9360812942      20181231   603015339530              1266400
# 344447003   US710415188      20010131    78130000000              1244000
# 344447004   US710415188      20000131    70349000000              1140000
# 344447108  CN9360812942      20201231   625667368468              1128767
#
#            operating_revenue_turnover  market_capitalisation_mil
# 344438669                 21313000000                       <NA>
# 344446988                482130000000                     212477
# 344446987                485873000000                     205104
# 344446986                500343000000                     318435
# 344446982                572754000000                     387815
# 344446983                559151000000                     397486
# 344446985                514405000000                     278411
# 344446992                446509000000                     210139
# 344446991                468651000000                     233999
# 344446990                476294000000                     241647
# 344446989                485651000000                     273906
# 344446984                523964000000                     324828
# 344446994                408085000000                     203577
# 344446995                404254000000                     184830
# 344446993                421849000000                     199721
# 344446996                377023000000                     203204
# 344447910                159342044679                       <NA>
# 344447909                165797925298                       <NA>
# 344446997                348368000000                     198761
# 344446998                312101000000                     203427
# 344446999                284310000000                     231178
# 344447012                469822000000                    1691002
# 344447000                258681000000                     237575
# 344447001                231577000000                     215372
# 344447002                205823000000                     270252
# 344447013                386064000000                    1634168
# 344447110                362154395615                       <NA>
# 344447003                193116000000                       <NA>
# 344447004                166809000000                       <NA>
# 344447108                284509153103                       <NA>

# %%
df.memory_usage(index=False, deep=True)/1e9
# Out:
# bvdid                         1.006917
# closing_date                  0.073186
# total_assets                  0.131734
# number_of_employees           0.073186
# operating_revenue_turnover    0.131734
# market_capitalisation_mil     0.073186
# dtype: float64

# %%
del key_financials

# %%
sql = """SELECT bvdid, closing_date, total_assets, number_of_employees, operating_revenue_turnover, market_capitalisation_mil FROM key_financials"""
key_financials = wr.athena.read_sql_query(sql, database="orbiskof2023")
key_financials

# %%
    SELECT *
    FROM firms_100_employees_or_10_mil_turnover_any_year
    INNER JOIN 
    (SELECT bvdid, closing_date, total_assets, capital, number_of_employees, operating_revenue_turnover, sales, gross_profit, research_and_development_expenses
    FROM "orbiskof2023"."global_financials_and_ratios")
    USING (bvdid)
    INNER JOIN
    (SELECT bvdid, name_internat, name_native, postcode, city, region_in_country, country_iso_code, website_address
    FROM "orbiskof2023"."contact_info")
    USING (bvdid)

# %% [markdown]
# # Firms w/ min. 100 employees or 10 mil turnover

# %%
sql = """CREATE TABLE firms_100_employees_or_10_mil_turnover_any_year
        WITH (
            format = 'Parquet',
            write_compression = 'SNAPPY',
            external_location = 's3://orbis-kof-2023/firms_100_employees_or_10_mil_turnover_any_year/'
        )
        AS (
            SELECT DISTINCT(bvdid)
            FROM key_financials
            WHERE number_of_employees >= 100
            OR operating_revenue_turnover >= 10000000
            OR market_capitalisation_mil > 0
        );"""

# %%
sql = """SELECT *
    FROM firms_100_employees_or_10_mil_turnover_any_year
    INNER JOIN 
    (SELECT bvdid, closing_date, number_of_employees, operating_revenue_turnover
    FROM "orbiskof2023"."key_financials")
    USING (bvdid)
    LEFT JOIN 
    (SELECT bvdid, closing_date, total_assets, added_value, research_and_development_expenses
    FROM "orbiskof2023"."global_financials_and_ratios")
    USING (bvdid, closing_date)
    INNER JOIN
    (SELECT bvdid, name_internat, name_native, postcode, city, region_in_country, country_iso_code, website_address
    FROM "orbiskof2023"."contact_info")
    USING (bvdid)
    INNER JOIN 
    (SELECT *
    FROM "orbiskof2023"."industry_classifications_small")
    USING (bvdid)
    """
df = wr.athena.read_sql_query(sql, database="orbiskof2023")
df
# Out:
#                bvdid  closing_date  number_of_employees
# 0         MY654509-A      20161231                 <NA>  \
# 1         MY654509-A      20161231                 <NA>
# 2         MY654509-A      20171231                 <NA>
# 3         MY654509-A      20171231                 <NA>
# 4         MY654509-A      20171231                 <NA>
# ...              ...           ...                  ...
# 75991421  RU76993305      20121231                  132
# 75991422  RU76993305      20121231                  132
# 75991423  RU76993305      20121231                  132
# 75991424  RU76993305      20121231                  132
# 75991425  RU76993305      20121231                  132
#
#           operating_revenue_turnover  total_assets  added_value
# 0                           21120375           NaN          NaN  \
# 1                           21120375           NaN          NaN
# 2                           24974889      158267.0     466204.0
# 3                           24974889      158267.0     466204.0
# 4                           24974889           NaN          NaN
# ...                              ...           ...          ...
# 75991421                     2832675      178483.0          NaN
# 75991422                     2832675      178483.0          NaN
# 75991423                     2832675      178483.0          NaN
# 75991424                     2832675      178483.0          NaN
# 75991425                     2832675      178483.0          NaN
#
#           research_and_development_expenses
# 0                                       NaN  \
# 1                                       NaN
# 2                                       NaN
# 3                                       NaN
# 4                                       NaN
# ...                                     ...
# 75991421                                NaN
# 75991422                                NaN
# 75991423                                NaN
# 75991424                                NaN
# 75991425                                NaN
#
#                                               name_internat
# 0                                     Jumbo Arena Sdn. Bhd.  \
# 1                                     Jumbo Arena Sdn. Bhd.
# 2                                     Jumbo Arena Sdn. Bhd.
# 3                                     Jumbo Arena Sdn. Bhd.
# 4                                     Jumbo Arena Sdn. Bhd.
# ...                                                     ...
# 75991421  Limited Liability Company Chukotzhilservis-Ugo...
# 75991422  Limited Liability Company Chukotzhilservis-Ugo...
# 75991423  Limited Liability Company Chukotzhilservis-Ugo...
# 75991424  Limited Liability Company Chukotzhilservis-Ugo...
# 75991425  Limited Liability Company Chukotzhilservis-Ugo...
#
#                            name_native postcode               city
# 0                Jumbo Arena Sdn. Bhd.    83000  Batu Pahat, Johor  \
# 1                Jumbo Arena Sdn. Bhd.    83000  Batu Pahat, Johor
# 2                Jumbo Arena Sdn. Bhd.    83000  Batu Pahat, Johor
# 3                Jumbo Arena Sdn. Bhd.    83000  Batu Pahat, Johor
# 4                Jumbo Arena Sdn. Bhd.    83000  Batu Pahat, Johor
# ...                                ...      ...                ...
# 75991421  Чукотжилсервис-Угольные Копи   689501   Pgt Ugolnye Kopi
# 75991422  Чукотжилсервис-Угольные Копи   689501   Pgt Ugolnye Kopi
# 75991423  Чукотжилсервис-Угольные Копи   689501   Pgt Ugolnye Kopi
# 75991424  Чукотжилсервис-Угольные Копи   689501   Pgt Ugolnye Kopi
# 75991425  Чукотжилсервис-Угольные Копи   689501   Pgt Ugolnye Kopi
#
#                                           region_in_country country_iso_code
# 0                                                     Johor               MY  \
# 1                                                     Johor               MY
# 2                                                     Johor               MY
# 3                                                     Johor               MY
# 4                                                     Johor               MY
# ...                                                     ...              ...
# 75991421  Far Eastern federal region|Chukotka Autonomous...               RU
# 75991422  Far Eastern federal region|Chukotka Autonomous...               RU
# 75991423  Far Eastern federal region|Chukotka Autonomous...               RU
# 75991424  Far Eastern federal region|Chukotka Autonomous...               RU
# 75991425  Far Eastern federal region|Chukotka Autonomous...               RU
#
#                 website_address ussic_primary_code
# 0         www.isuzu3s-sales.com               5511  \
# 1         www.isuzu3s-sales.com               5012
# 2         www.isuzu3s-sales.com               5511
# 3         www.isuzu3s-sales.com               5012
# 4         www.isuzu3s-sales.com               5511
# ...                         ...                ...
# 75991421
# 75991422
# 75991423
# 75991424
# 75991425
#
#          nace_rev_2_core_code_4_digits
# 0
# 1                                 4511
# 2
# 3                                 4511
# 4
# ...                                ...
# 75991421
# 75991422
# 75991423
# 75991424
# 75991425
#
# [75991426 rows x 16 columns]

# %%
df['count_na'] = df.isnull().sum(axis=1)
df.sort_values(['bvdid', 'closing_date', 'number_of_employees', 'operating_revenue_turnover', 
                'research_and_development_expenses', 'count_na'], 
               ascending=[True, True, False, False, False, False], 
               inplace=True)
df.drop(columns='count_na', inplace=True)
df.drop_duplicates(subset=['bvdid', 'closing_date'], inplace=True)
df
# Out:
#                  bvdid  closing_date  number_of_employees
# 41708417    ADFEB18424      20051231                 <NA>  \
# 41708418    ADFEB18424      20061231                 <NA>
# 41708419    ADFEB18424      20071231                 <NA>
# 41708420    ADFEB18424      20081231                 <NA>
# 41708421    ADFEB18424      20091231                 <NA>
# ...                ...           ...                  ...
# 30539797  ZWFEI1025337      20161231                 <NA>
# 30539802  ZWFEI1025337      20171231                 <NA>
# 30539807  ZWFEI1025337      20181231                 <NA>
# 30539812  ZWFEI1025337      20191231                 <NA>
# 30539817  ZWFEI1025337      20201231                 <NA>
#
#           operating_revenue_turnover  total_assets  added_value
# 41708417                   154719400           NaN          NaN  \
# 41708418                   196295277           NaN          NaN
# 41708419                   224536363           NaN          NaN
# 41708420                   163303389           NaN          NaN
# 41708421                   196551196           NaN          NaN
# ...                              ...           ...          ...
# 30539797                    13841000           NaN          NaN
# 30539802                    15267000           NaN          NaN
# 30539807                          27           NaN          NaN
# 30539812                         247           NaN          NaN
# 30539817                         299           NaN          NaN
#
#           research_and_development_expenses
# 41708417                                NaN  \
# 41708418                                NaN
# 41708419                                NaN
# 41708420                                NaN
# 41708421                                NaN
# ...                                     ...
# 30539797                                NaN
# 30539802                                NaN
# 30539807                                NaN
# 30539812                                NaN
# 30539817                                NaN
#
#                                    name_internat
# 41708417  Andorra Banc Agricol Reig SA - AndBank  \
# 41708418  Andorra Banc Agricol Reig SA - AndBank
# 41708419  Andorra Banc Agricol Reig SA - AndBank
# 41708420  Andorra Banc Agricol Reig SA - AndBank
# 41708421  Andorra Banc Agricol Reig SA - AndBank
# ...                                          ...
# 30539797         Grand Reinsurance (Private) Ltd
# 30539802         Grand Reinsurance (Private) Ltd
# 30539807         Grand Reinsurance (Private) Ltd
# 30539812         Grand Reinsurance (Private) Ltd
# 30539817         Grand Reinsurance (Private) Ltd
#
#                                      name_native postcode                city
# 41708417  Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany  \
# 41708418  Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany
# 41708419  Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany
# 41708420  Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany
# 41708421  Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany
# ...                                          ...      ...                 ...
# 30539797         Grand Reinsurance (Private) Ltd                       Harare
# 30539802         Grand Reinsurance (Private) Ltd                       Harare
# 30539807         Grand Reinsurance (Private) Ltd                       Harare
# 30539812         Grand Reinsurance (Private) Ltd                       Harare
# 30539817         Grand Reinsurance (Private) Ltd                       Harare
#
#          region_in_country country_iso_code    website_address
# 41708417                                 AD    www.andbank.com  \
# 41708418                                 AD    www.andbank.com
# 41708419                                 AD    www.andbank.com
# 41708420                                 AD    www.andbank.com
# 41708421                                 AD    www.andbank.com
# ...                    ...              ...                ...
# 30539797            Harare               ZW  www.grandre.co.zw
# 30539802            Harare               ZW  www.grandre.co.zw
# 30539807            Harare               ZW  www.grandre.co.zw
# 30539812            Harare               ZW  www.grandre.co.zw
# 30539817            Harare               ZW  www.grandre.co.zw
#
#          ussic_primary_code nace_rev_2_core_code_4_digits
# 41708417               6282                          6619
# 41708418               6282                          6619
# 41708419               6282                          6619
# 41708420               6282                          6619
# 41708421               6282                          6619
# ...                     ...                           ...
# 30539797
# 30539802
# 30539807
# 30539812
# 30539817
#
# [19421420 rows x 16 columns]

# %%
df.bvdid.nunique()
# Out:
# 4062446

# %%
df.name_internat.nunique()
# Out:
# 3892412

# %%
df.closing_date.apply(str).str[:4].value_counts().sort_index()
# Out:
# closing_date
# 1935          1
# 1936          1
# 1968          8
# 1970          3
# 1972          1
# 1973          2
# 1974          1
# 1975          1
# 1976          2
# 1977          1
# 1979          1
# 1980          9
# 1981        183
# 1982        639
# 1983       1674
# 1984       3073
# 1985       3688
# 1986       4607
# 1987       5999
# 1988       7786
# 1989       9099
# 1990      13635
# 1991      18770
# 1992      24563
# 1993      31977
# 1994      37134
# 1995      45489
# 1996      56203
# 1997      67445
# 1998      80912
# 1999      98536
# 2000     116555
# 2001     143325
# 2002     171638
# 2003     195951
# 2004     212434
# 2005     235395
# 2006     423676
# 2007     474597
# 2008     533562
# 2009     550444
# 2010     580958
# 2011     734620
# 2012    1187073
# 2013    1381345
# 2014    1461614
# 2015    1380680
# 2016    1349141
# 2017    1382679
# 2018    1380776
# 2019    1342563
# 2020    1463894
# 2021    2062085
# 2022     144972
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# bvdid                                 object
# closing_date                           Int32
# number_of_employees                    Int32
# operating_revenue_turnover             Int64
# total_assets                         float32
# added_value                          float32
# research_and_development_expenses    float32
# name_internat                         object
# name_native                           object
# postcode                              object
# city                                  object
# region_in_country                     object
# country_iso_code                      object
# website_address                       object
# ussic_primary_code                    object
# nace_rev_2_core_code_4_digits         object
# dtype: object

# %%
wr.s3.to_parquet(df, path="""s3://orbis-kof-2023/firms_100_employees_or_10_mil_turnover_any_year_full/
                             firms_100_employees_or_10_mil_turnover_any_year_full.parquet""")
# Out:
# {'paths': ['s3://orbis-kof-2023/firms_100_employees_or_10_mil_turnover_any_year_full/\n                             firms_100_employees_or_10_mil_turnover_any_year_full.parquet'],
#  'partitions_values': {}}

# %% [markdown]
# # Read orbis (firms w/ min. 100 employees or 10 mil turnover)

# %%
import pandas as pd
import awswrangler as wr

# %%
df = wr.s3.read_parquet('s3://orbis-kof-2023/firms_100_employees_or_10_mil_turnover_any_year_full/')

# %%
for col, dtype in df.dtypes.items():
    if dtype=='string':
        df[col] = df[col].astype(str)

# %%
df['cleaned_name'] = df.name_internat.swifter.apply(firm_name_clean)
# Out:
# Pandas Apply:   0%|          | 0/19421420 [00:00<?, ?it/s]

# %% [markdown]
# # Read compustat

# %%
def firm_name_clean(firm_name, lower=True, remove_punc=True, remove_legal=True, remove_parentheses=True):
    # make string
    firm_name = str(firm_name)
    firm_name = unidecode.unidecode(firm_name)
    # lowercase
    if lower:
        firm_name = firm_name.lower()
    # remove punctuation
    if remove_punc:
        firm_name = firm_name.translate(str.maketrans('', '', '!"#$%\\\'*+,./:;<=>?@^_`{|}~'))
    # remove legal identifiers
    if remove_legal:
        legal_identifiers = ["co", "inc", "ag", "ltd", "lp", "llc", "pllc", "llp", "plc", "ltdplc", "corp",
                             "corporation", "ab", "cos", "cia", "sa", "company", "companies", "consolidated",
                             "stores", "limited", "srl", "kk", "gmbh", "pty", "group", "yk", "bhd",
                             "limitada", "holdings", "kg", "bv", "pte", "sas", "ilp", "nl", "genossenschaft",
                             "gesellschaft", "aktiengesellschaft", "ltda", "nv", "oao", "holding", "se",
                             "oy", "plcnv", "the", "neft", "& co", "&co", "(u.k.)", "uk", "south africa",
                             "vietnman", "S/a", "& co"]
        pattern = '|'.join(legal_identifiers)
        pattern = '\\b(' + pattern + ')\\b'  # match only word boundaries
        firm_name = re.sub(pattern, '', firm_name)
    # remove parentheses and anything in them: Bayerische Motoren Werke (BMW) -> Bayerische Motoren Werke
    if remove_parentheses:
        firm_name = re.sub(r'\([^()]*\)', '', firm_name)

    # make hyphens consistent
    firm_name = firm_name.replace(' - ', '-')

    # remove ampersand symbol
    firm_name = firm_name.replace('&amp;', '&')
    firm_name = firm_name.replace('&amp', '&')

    # strip
    firm_name = firm_name.strip()

    return firm_name


def firm_name_matching(df, df_lookup, firm_name_col='company', clean_lookup=True):
    assert not df[firm_name_col].duplicated().any(), 'Firm names to match contain duplicates!'
    assert not df_lookup[firm_name_col].duplicated().any(), 'Lookup firm list contains duplicates!'

    df['match_col'] = df[firm_name_col].apply(firm_name_clean)
    if clean_lookup:
        df_lookup['match_col'] = df_lookup[firm_name_col].apply(firm_name_clean)
    else:
        df_lookup['match_col'] = df_lookup[firm_name_col]

    res = df.merge(df_lookup, on='match_col', how='left', indicator=True)
    print(f'Matched {(res._merge == "both").sum()/len(df)*100} percent of companies')

    # res = res.drop(columns=['_merge', 'match_col'])

    return res

# %%
compustat_na = pd.read_csv('compustat_na_lexis.csv')
compustat_global = pd.read_csv('compustat_global_lexis.csv')
compustat = pd.concat([compustat_global, compustat_na]).drop_duplicates(subset=['gvkey', 'fyear'])
compustat
# Out:
#          gvkey   fyear    datadate         at     emp       revt       sale
# 0         1166  1996.0  1996-12-31    611.980   4.140    658.238    658.238  \
# 1         1166  1997.0  1997-12-31    724.115   4.514    708.673    708.673
# 2         1166  1998.0  1998-12-31    623.539   4.436    634.913    634.913
# 3         1166  1999.0  1999-12-31    425.035   5.426    414.495    414.495
# 4         1166  2000.0  2000-12-31    777.940   6.491    935.212    935.212
# ...        ...     ...         ...        ...     ...        ...        ...
# 605298  351491  2019.0  2019-12-31  17847.000  32.525  13408.000  13408.000
# 605299  351491  2020.0  2020-12-31  18841.000  32.632  12549.000  12549.000
# 605300  351491  2021.0  2021-12-31  18834.114  34.132  14388.308  14388.308
# 605301  351491  2022.0  2022-12-31  17113.769  35.611  15343.932  15343.932
# 605308  353945  2021.0  2021-12-31        NaN     NaN        NaN        NaN
#
#             xrd                      conm   addzip  ...     naics     sic
# 0        57.599      ASM INTERNATIONAL NV  1322 AP  ...  333242.0  3559.0  \
# 1        85.944      ASM INTERNATIONAL NV  1322 AP  ...  333242.0  3559.0
# 2        79.945      ASM INTERNATIONAL NV  1322 AP  ...  333242.0  3559.0
# 3        47.145      ASM INTERNATIONAL NV  1322 AP  ...  333242.0  3559.0
# 4        73.800      ASM INTERNATIONAL NV  1322 AP  ...  333242.0  3559.0
# ...         ...                       ...      ...  ...       ...     ...
# 605298  521.000           IVECO GROUP N V    10156  ...  336120.0  3711.0
# 605299  526.000           IVECO GROUP N V    10156  ...  336120.0  3711.0
# 605300  547.054           IVECO GROUP N V    10156  ...  336120.0  3711.0
# 605301  505.515           IVECO GROUP N V    10156  ...  336120.0  3711.0
# 605308      NaN  ACCELLERON INDUSTRIES AG     5400  ...  335312.0  3621.0
#
#                            weburl  indfmt  consol popsrc datafmt    tic curcd
# 0                     www.asm.com     NaN     NaN    NaN     NaN    NaN   NaN  \
# 1                     www.asm.com     NaN     NaN    NaN     NaN    NaN   NaN
# 2                     www.asm.com     NaN     NaN    NaN     NaN    NaN   NaN
# 3                     www.asm.com     NaN     NaN    NaN     NaN    NaN   NaN
# 4                     www.asm.com     NaN     NaN    NaN     NaN    NaN   NaN
# ...                           ...     ...     ...    ...     ...    ...   ...
# 605298         www.ivecogroup.com    INDL       C      D     STD  IVCGF   USD
# 605299         www.ivecogroup.com    INDL       C      D     STD  IVCGF   USD
# 605300         www.ivecogroup.com    INDL       C      D     STD  IVCGF   USD
# 605301         www.ivecogroup.com    INDL       C      D     STD  IVCGF   USD
# 605308  accelleron-industries.com    INDL       C      D     STD  ACLLY   USD
#
#        costat
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
# ...       ...
# 605298      A
# 605299      A
# 605300      A
# 605301      A
# 605308      A
#
# [1411998 rows x 23 columns]

# %%
compustat.columns
# Out:
# Index(['gvkey', 'fyear', 'datadate', 'at', 'emp', 'revt', 'sale', 'xrd',
#        'conm', 'addzip', 'city', 'conml', 'loc', 'naics', 'sic', 'weburl',
#        'indfmt', 'consol', 'popsrc', 'datafmt', 'tic', 'curcd', 'costat'],
#       dtype='object')

# %%
compustat_renamed = compustat[['gvkey', 'fyear', 'emp', 'revt', 'at', 'xrd', 'conm', 'addzip', 
                              'city', 'loc', 'weburl', 'sic', 'naics']].copy()
compustat_renamed.columns = ['bvdid', 'closing_date', 'number_of_employees',
       'operating_revenue_turnover', 'total_assets', 'research_and_development_expenses', 'name_internat',
       'postcode', 'city', 'country_iso_code',
       'website_address', 'ussic_primary_code',
       'naics_primary_code']
compustat_renamed['from_compustat'] = 1
compustat_renamed['cleaned_name'] = compustat_renamed.name_internat.swifter.apply(firm_name_clean)
compustat_renamed['number_of_employees'] = compustat_renamed.number_of_employees * 1e3
compustat_renamed['total_assets'] = compustat_renamed.total_assets * 1e6
compustat_renamed['operating_revenue_turnover'] = compustat_renamed.operating_revenue_turnover * 1e6
compustat_renamed['research_and_development_expenses'] = compustat_renamed.research_and_development_expenses * 1e6
# Out:
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/swifter/swifter.py:87: UserWarning: This pandas object has duplicate indices, and swifter may not be able to improve performance. Consider resetting the indices with `df.reset_index(drop=True)`.
#   warnings.warn(
# Pandas Apply:   0%|          | 0/1411998 [00:00<?, ?it/s]

# %%
orbis_merged_compustat = pd.concat([df, compustat_renamed])
orbis_merged_compustat['from_compustat'] = orbis_merged_compustat.from_compustat.fillna(0)
orbis_merged_compustat['bvdid'] = orbis_merged_compustat.bvdid.astype(str)
orbis_merged_compustat
# Out:
#              bvdid  closing_date  number_of_employees
# 0       ADFEB18424    20051231.0                 <NA>  \
# 1       ADFEB18424    20061231.0                 <NA>
# 2       ADFEB18424    20071231.0                 <NA>
# 3       ADFEB18424    20081231.0                 <NA>
# 4       ADFEB18424    20091231.0                 <NA>
# ...            ...           ...                  ...
# 605298      351491        2019.0              32525.0
# 605299      351491        2020.0              32632.0
# 605300      351491        2021.0              34132.0
# 605301      351491        2022.0              35611.0
# 605308      353945        2021.0                 <NA>
#
#         operating_revenue_turnover  total_assets  added_value
# 0                      154719400.0           NaN          NaN  \
# 1                      196295277.0           NaN          NaN
# 2                      224536363.0           NaN          NaN
# 3                      163303389.0           NaN          NaN
# 4                      196551196.0           NaN          NaN
# ...                            ...           ...          ...
# 605298               13408000000.0  1.784700e+10          NaN
# 605299               12549000000.0  1.884100e+10          NaN
# 605300               14388308000.0  1.883411e+10          NaN
# 605301               15343932000.0  1.711377e+10          NaN
# 605308                        <NA>           NaN          NaN
#
#         research_and_development_expenses
# 0                                     NaN  \
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 605298                        521000000.0
# 605299                        526000000.0
# 605300                        547054000.0
# 605301                        505515000.0
# 605308                                NaN
#
#                                  name_internat
# 0       Andorra Banc Agricol Reig SA - AndBank  \
# 1       Andorra Banc Agricol Reig SA - AndBank
# 2       Andorra Banc Agricol Reig SA - AndBank
# 3       Andorra Banc Agricol Reig SA - AndBank
# 4       Andorra Banc Agricol Reig SA - AndBank
# ...                                        ...
# 605298                         IVECO GROUP N V
# 605299                         IVECO GROUP N V
# 605300                         IVECO GROUP N V
# 605301                         IVECO GROUP N V
# 605308                ACCELLERON INDUSTRIES AG
#
#                                    name_native postcode                city
# 0       Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany  \
# 1       Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany
# 2       Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany
# 3       Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany
# 4       Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany
# ...                                        ...      ...                 ...
# 605298                                     NaN    10156               Turin
# 605299                                     NaN    10156               Turin
# 605300                                     NaN    10156               Turin
# 605301                                     NaN    10156               Turin
# 605308                                     NaN     5400               Baden
#
#        region_in_country country_iso_code            website_address
# 0                                      AD            www.andbank.com  \
# 1                                      AD            www.andbank.com
# 2                                      AD            www.andbank.com
# 3                                      AD            www.andbank.com
# 4                                      AD            www.andbank.com
# ...                  ...              ...                        ...
# 605298               NaN              ITA         www.ivecogroup.com
# 605299               NaN              ITA         www.ivecogroup.com
# 605300               NaN              ITA         www.ivecogroup.com
# 605301               NaN              ITA         www.ivecogroup.com
# 605308               NaN              CHE  accelleron-industries.com
#
#        ussic_primary_code nace_rev_2_core_code_4_digits
# 0                    6282                          6619  \
# 1                    6282                          6619
# 2                    6282                          6619
# 3                    6282                          6619
# 4                    6282                          6619
# ...                   ...                           ...
# 605298             3711.0                           NaN
# 605299             3711.0                           NaN
# 605300             3711.0                           NaN
# 605301             3711.0                           NaN
# 605308             3621.0                           NaN
#
#                               cleaned_name  naics_primary_code  from_compustat
# 0       andorra banc agricol reig -andbank                 NaN             0.0
# 1       andorra banc agricol reig -andbank                 NaN             0.0
# 2       andorra banc agricol reig -andbank                 NaN             0.0
# 3       andorra banc agricol reig -andbank                 NaN             0.0
# 4       andorra banc agricol reig -andbank                 NaN             0.0
# ...                                    ...                 ...             ...
# 605298                          iveco  n v            336120.0             1.0
# 605299                          iveco  n v            336120.0             1.0
# 605300                          iveco  n v            336120.0             1.0
# 605301                          iveco  n v            336120.0             1.0
# 605308               accelleron industries            335312.0             1.0
#
# [20833418 rows x 19 columns]

# %%
orbis_merged_compustat.columns
# Out:
# Index(['bvdid', 'closing_date', 'number_of_employees',
#        'operating_revenue_turnover', 'total_assets', 'added_value',
#        'research_and_development_expenses', 'name_internat', 'name_native',
#        'postcode', 'city', 'region_in_country', 'country_iso_code',
#        'website_address', 'ussic_primary_code',
#        'nace_rev_2_core_code_4_digits', 'cleaned_name', 'naics_primary_code',
#        'from_compustat'],
#       dtype='object')

# %%
df_static = orbis_merged_compustat[['bvdid', 'name_internat', 'name_native',
       'postcode', 'city', 'region_in_country', 'country_iso_code',
       'website_address', 'ussic_primary_code',
       'nace_rev_2_core_code_4_digits', 'cleaned_name', 'from_compustat']]
df_static
# Out:
#              bvdid                           name_internat
# 0       ADFEB18424  Andorra Banc Agricol Reig SA - AndBank  \
# 1       ADFEB18424  Andorra Banc Agricol Reig SA - AndBank
# 2       ADFEB18424  Andorra Banc Agricol Reig SA - AndBank
# 3       ADFEB18424  Andorra Banc Agricol Reig SA - AndBank
# 4       ADFEB18424  Andorra Banc Agricol Reig SA - AndBank
# ...            ...                                     ...
# 605298      351491                         IVECO GROUP N V
# 605299      351491                         IVECO GROUP N V
# 605300      351491                         IVECO GROUP N V
# 605301      351491                         IVECO GROUP N V
# 605308      353945                ACCELLERON INDUSTRIES AG
#
#                                    name_native postcode                city
# 0       Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany  \
# 1       Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany
# 2       Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany
# 3       Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany
# 4       Andorra Banc Agricol Reig SA - AndBank           Escaldes-Engordany
# ...                                        ...      ...                 ...
# 605298                                     NaN    10156               Turin
# 605299                                     NaN    10156               Turin
# 605300                                     NaN    10156               Turin
# 605301                                     NaN    10156               Turin
# 605308                                     NaN     5400               Baden
#
#        region_in_country country_iso_code            website_address
# 0                                      AD            www.andbank.com  \
# 1                                      AD            www.andbank.com
# 2                                      AD            www.andbank.com
# 3                                      AD            www.andbank.com
# 4                                      AD            www.andbank.com
# ...                  ...              ...                        ...
# 605298               NaN              ITA         www.ivecogroup.com
# 605299               NaN              ITA         www.ivecogroup.com
# 605300               NaN              ITA         www.ivecogroup.com
# 605301               NaN              ITA         www.ivecogroup.com
# 605308               NaN              CHE  accelleron-industries.com
#
#        ussic_primary_code nace_rev_2_core_code_4_digits
# 0                    6282                          6619  \
# 1                    6282                          6619
# 2                    6282                          6619
# 3                    6282                          6619
# 4                    6282                          6619
# ...                   ...                           ...
# 605298             3711.0                           NaN
# 605299             3711.0                           NaN
# 605300             3711.0                           NaN
# 605301             3711.0                           NaN
# 605308             3621.0                           NaN
#
#                               cleaned_name  from_compustat
# 0       andorra banc agricol reig -andbank             0.0
# 1       andorra banc agricol reig -andbank             0.0
# 2       andorra banc agricol reig -andbank             0.0
# 3       andorra banc agricol reig -andbank             0.0
# 4       andorra banc agricol reig -andbank             0.0
# ...                                    ...             ...
# 605298                          iveco  n v             1.0
# 605299                          iveco  n v             1.0
# 605300                          iveco  n v             1.0
# 605301                          iveco  n v             1.0
# 605308               accelleron industries             1.0
#
# [20833418 rows x 12 columns]

# %%
df_dynamic = orbis_merged_compustat[['bvdid', 'closing_date', 'number_of_employees',
       'operating_revenue_turnover', 'total_assets', 'added_value',
       'research_and_development_expenses']]
df_dynamic
# Out:
#              bvdid  closing_date  number_of_employees
# 0       ADFEB18424    20051231.0                 <NA>  \
# 1       ADFEB18424    20061231.0                 <NA>
# 2       ADFEB18424    20071231.0                 <NA>
# 3       ADFEB18424    20081231.0                 <NA>
# 4       ADFEB18424    20091231.0                 <NA>
# ...            ...           ...                  ...
# 605298      351491        2019.0              32525.0
# 605299      351491        2020.0              32632.0
# 605300      351491        2021.0              34132.0
# 605301      351491        2022.0              35611.0
# 605308      353945        2021.0                 <NA>
#
#         operating_revenue_turnover  total_assets  added_value
# 0                      154719400.0           NaN          NaN  \
# 1                      196295277.0           NaN          NaN
# 2                      224536363.0           NaN          NaN
# 3                      163303389.0           NaN          NaN
# 4                      196551196.0           NaN          NaN
# ...                            ...           ...          ...
# 605298               13408000000.0  1.784700e+10          NaN
# 605299               12549000000.0  1.884100e+10          NaN
# 605300               14388308000.0  1.883411e+10          NaN
# 605301               15343932000.0  1.711377e+10          NaN
# 605308                        <NA>           NaN          NaN
#
#         research_and_development_expenses
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ...                                   ...
# 605298                        521000000.0
# 605299                        526000000.0
# 605300                        547054000.0
# 605301                        505515000.0
# 605308                                NaN
#
# [20833418 rows x 7 columns]

# %%
df_static = df_static.set_index('bvdid').sort_index()

# %%
max_per_bvdid_all_years = df_dynamic.groupby('bvdid')[['number_of_employees', 'operating_revenue_turnover']].max()
max_per_bvdid_all_years.columns = ['max_number_of_employees', 'max_turnover']
df_static = df_static.merge(max_per_bvdid_all_years, left_index=True, right_index=True)

# %%
df_static = df_static.sort_values(['from_compustat', 'max_number_of_employees', 'max_turnover'], ascending=False)
df_static = df_static.reset_index().drop_duplicates(subset=['cleaned_name'], keep='first')
df_static
# Out:
#                  bvdid                                      name_internat
# 0               210637                       UCOM-UNITED COMMUNICATON IND  \
# 10               11259                                        WALMART INC
# 63               64768                                     AMAZON.COM INC
# 91               61994                       UNITED STATES POSTAL SERVICE
# 120             203177                       HON HAI PRECISION IND CO LTD
# ...                ...                                                ...
# 20833362     US69204NU  Global X FDS Autonomous and Electric Vehicles ETF
# 20833366     MN40136OI                    Bayan Aldar Joint Stock Company
# 20833376     NP124272R                       Chhyangdi Hydropower Limited
# 20833381   US841384961                                 Hinto Energy, Inc.
# 20833397  IN0010708533                            Srestha Finvest Limited
#
#                                                 name_native    postcode
# 0                                                       NaN       10900  \
# 10                                                      NaN       72716
# 63                                                      NaN  98109-5210
# 91                                                      NaN  20260-0546
# 120                                                     NaN         236
# ...                                                     ...         ...
# 20833362  Global X FDS Autonomous and Electric Vehicles ETF       10022
# 20833366                    Bayan Aldar Joint Stock Company
# 20833376                       Chhyangdi Hydropower Limited
# 20833381                                 Hinto Energy, Inc.       80111
# 20833397                            Srestha Finvest Limited      600003
#
#                           city region_in_country country_iso_code
# 0                      Bangkok               NaN              THA  \
# 10                 Bentonville               NaN              USA
# 63                     Seattle               NaN              USA
# 91                  Washington               NaN              USA
# 120            New Taipei City               NaN              TWN
# ...                        ...               ...              ...
# 20833362              New York          New York               US
# 20833366          Uliastai Sum                                 MN
# 20833376  Kathmandu, Kathmandu                                 NP
# 20833381     Greenwood Village          Colorado               US
# 20833397               Chennai        Tamil Nadu               IN
#
#                 website_address ussic_primary_code
# 0                           NaN             4810.0  \
# 10        www.stock.walmart.com             5331.0
# 63          www.aboutamazon.com             5961.0
# 91                 www.usps.gov             4210.0
# 120             www.foxconn.com             3674.0
# ...                         ...                ...
# 20833362   www.globalxfunds.com               6722
# 20833366                                      2099
# 20833376            chpl.com.np
# 20833381    www.hintoenergy.com               6726
# 20833397          srestha.co.in               6159
#
#          nace_rev_2_core_code_4_digits
# 0                                  NaN  \
# 10                                 NaN
# 63                                 NaN
# 91                                 NaN
# 120                                NaN
# ...                                ...
# 20833362                          6420
# 20833366                          1089
# 20833376
# 20833381                          6430
# 20833397                          6499
#
#                                                cleaned_name  from_compustat
# 0                              ucom-united communicaton ind             1.0  \
# 10                                                  walmart             1.0
# 63                                                amazoncom             1.0
# 91                             united states postal service             1.0
# 120                                   hon hai precision ind             1.0
# ...                                                     ...             ...
# 20833362  global x fds autonomous and electric vehicles etf             0.0
# 20833366                            bayan aldar joint stock             0.0
# 20833376                               chhyangdi hydropower             0.0
# 20833381                                       hinto energy             0.0
# 20833397                                    srestha finvest             0.0
#
#           max_number_of_employees     max_turnover
# 0                       4855000.0    36815892000.0
# 10                      2300000.0   608481000000.0
# 63                      1608000.0   513983000000.0
# 91                       905766.0    78620000000.0
# 120                      878429.0  6626996750000.0
# ...                           ...              ...
# 20833362                     <NA>         487000.0
# 20833366                     <NA>         485376.0
# 20833376                     <NA>         484996.0
# 20833381                     <NA>         475630.0
# 20833397                     <NA>         472137.0
#
# [3784619 rows x 14 columns]

# %% [markdown]
# # Firm name matching

# %%
lexis_firm_names_clean = pd.read_csv('lexis_firm_names_clean.csv')
lexis_firm_names_clean
# Out:
#                                 cleaned_name
# 0                                  microsoft
# 1            international business machines
# 2                                    siemens
# 3                                 mitsubishi
# 4                           american express
# ...                                      ...
# 132023  compania paraguaya de comunicaciones
# 132024                                cencar
# 132025                                 censu
# 132026                  bebidas del paraguay
# 132027                        digital hearts
#
# [132028 rows x 1 columns]

# %%
df_static.cleaned_name.nunique()
# Out:
# 3784619

# %%
to_remove = ['federal reserve', 'eu', 'fed', 'treasury', 'congress', 'european central bank',
             'international monetary fund', 'central bank', 'senate', 'white house', 'house', 'sec',
             'ecb', 'european commission', 'state', 'un', 'bank of england', 'opec', 'supreme court',
             'world bank', 'pentagon', 'cabinet', 'web service', 'us senate', 'imf', 'defense',
             'federal reserve bank' 'euro', 'house of representatives', 'bank', 'journal',
             'us bankruptcy court', 'medicare', 'american international', 'finance', 's&p', 's&p 500',
             'news', 'united nations', 'nasdaq', 'parliament', 'us treasury department', 'romney',
             'draghi', 'usda', 'cotton', 'district court', 'army', '', '&', np.nan, None, 'NYSE',
             'Newstex', 'NASDAQ', 'GLOBE NEWSWIRE', 'Zacks Investment Research', 'Reuters', 'ASX',
             'Nasdaq', 'TSX', 'LSE', 'JV', 'Thomson Reuters', 'Wall Street Journal', 'OTC', 'M',
             'Financial Times', 'The European Commission', 'T', 'NYSE MKT', 'TSXV', 'OTCQB',
             'BUSINESS TIMES MALAYSIA', 'fdch', 'WORLDSOURCES', 'WORLD TIMES', 'ASX',
             'WORLDSOURCES ONLINE', 'OTCBB', 'ASIA WorldSources Online', 'GLOBE NEWSWIRE',
             'AFX', 'PRNewswire-FirstCall', 'ASIA WorldSources', 'Reuters', 'ANSA', 'PR Newswire',
             'TSX VENTURE', 'RTTNews', 'ENP Newswire', 'M2 COMMUNICATIONS', 'OTCQB',
             'OTC Bulletin Board', 'Xinhua', 'CSE', '-', 'Joint Venture', 'Alliance News',
             'Interfax', 'JAKARTA POST', 'SeeNews', 'EU', 'Company', 'Asia Pulse', 'dpa-AFX',
             'JAKARTA POST ASIA WorldSources', 'XFN-ASIA', 'Financial Times', 'FDA', 'News Corp',
             'WORLD TIMES', 'RWE Australian Business News', 'TSXV', 'AAP', 'BUSINESS TIMES',
             'TSE', 'AP', 'HT Digital Content Services', 'ASIA WorldSources Online', 'EPA',
             'AIM', 'TSX VENTURE', 'Government', 'ICB', 'ICB', 'European Union', 'RWE Aust Business News',
             'JAKARTA POST INDONESIA', 'NRL', 'Newsfile', '', 'BSE', '', 'NSE', 'isis', 'ase',
             'united states navy', 'ule', 'aex', 'Undisclosed JV Partner', 'Undisclosed Chinese Co', 
             'Undisclosed JV Partner', 'Undisclosed Chinese Co', 'Peoples Republic of China', 'Malaysia',
                  'Ministry of Finance Singapore', 'Singapore', 'Russian Federation',
                  'Undisclosed Japanese Partner', 'Saudi Arabia', 'Indonesia Republic', 'Republic of Korea',
                  'Undisclosed Companies', 'Philippines', 'Algerian Government', 'Undisclosed Japanese Co(s)',
                  'Seeking Partner', 'Vietnam', 'Soviet Union', 'Kazakhstan', 'Undisclosed US Partner',
                  'Uzbekistan', 'Undisclosed Russian Partner', 'Kingdom of Spain', 'Iran', 'Shareholders',
                  'Undisclosed Thai Co', 'Pakistan', 'South Africa', 'Undisclosed Australian Partner',
                  'Republic of Ireland', 'Russian Regional Government', 'Cambodia', 'Ukraine',
                  'Undisclosed American Co', 'Chile', 'Undisclosed', 'joint venture electronics', 'european commission', 'news']
to_remove = [firm_name_clean(elem) for elem in to_remove]
lexis_firm_names_clean.drop(lexis_firm_names_clean[lexis_firm_names_clean.cleaned_name.isin(to_remove)].index, inplace=True)

# drop firm names with only one character
lexis_firm_names_clean.drop(lexis_firm_names_clean[lexis_firm_names_clean.cleaned_name.str.len() < 2].index, inplace=True)

lexis_firm_names_clean.drop_duplicates(inplace=True)

# %%
res = firm_name_matching(lexis_firm_names_clean, 
                             df_static, 
                             firm_name_col='cleaned_name', clean_lookup=False)
res
# Out:
# Matched 61.33457564463837 percent of companies
#                               cleaned_name_x
# 0                                  microsoft  \
# 1            international business machines
# 2                                    siemens
# 3                                 mitsubishi
# 4                           american express
# ...                                      ...
# 132007  compania paraguaya de comunicaciones
# 132008                                cencar
# 132009                                 censu
# 132010                  bebidas del paraguay
# 132011                        digital hearts
#
#                                    match_col            bvdid
# 0                                  microsoft            12141  \
# 1            international business machines      US130871985
# 2                                    siemens            19349
# 3                                 mitsubishi           100555
# 4                           american express             1447
# ...                                      ...              ...
# 132007  compania paraguaya de comunicaciones              NaN
# 132008                                cencar  TH0105537065095
# 132009                                 censu              NaN
# 132010                  bebidas del paraguay              NaN
# 132011                        digital hearts           288095
#
#                                name_internat
# 0                             MICROSOFT CORP  \
# 1       International Business Machines Corp
# 2                                 SIEMENS AG
# 3                            MITSUBISHI CORP
# 4                        AMERICAN EXPRESS CO
# ...                                      ...
# 132007                                   NaN
# 132008                            Cencar LTD
# 132009                                   NaN
# 132010                                   NaN
# 132011            DIGITAL HEARTS HOLDINGS CO
#
#                                  name_native    postcode
# 0                                        NaN  98052-6399  \
# 1       International Business Machines Corp       10504
# 2                                        NaN       80333
# 3                                        NaN    100-8086
# 4                                        NaN       10285
# ...                                      ...         ...
# 132007                                   NaN         NaN
# 132008                     บจ.เซ็นคาร์ จำกัด       12130
# 132009                                   NaN         NaN
# 132010                                   NaN         NaN
# 132011                                   NaN    163-1441
#
#                            city region_in_country country_iso_code
# 0                       Redmond               NaN              USA  \
# 1                        Armonk          New York               US
# 2                        Munich               NaN              DEU
# 3                         Tokyo               NaN              JPN
# 4                      New York               NaN              USA
# ...                         ...               ...              ...
# 132007                      NaN               NaN              NaN
# 132008  Lam Luk Ka, Pathumthani                                 TH
# 132009                      NaN               NaN              NaN
# 132010                      NaN               NaN              NaN
# 132011                    Tokyo               NaN              JPN
#
#                  website_address ussic_primary_code
# 0              www.microsoft.com             7372.0  \
# 1                    www.ibm.com
# 2                www.siemens.com             9997.0
# 3         www.mitsubishicorp.com             5099.0
# 4        www.americanexpress.com             6141.0
# ...                          ...                ...
# 132007                       NaN                NaN
# 132008            www.cencar.com               6531
# 132009                       NaN                NaN
# 132010                       NaN                NaN
# 132011  www.digitalhearts-hd.com             7370.0
#
#        nace_rev_2_core_code_4_digits                   cleaned_name_y
# 0                                NaN                        microsoft  \
# 1                                     international business machines
# 2                                NaN                          siemens
# 3                                NaN                       mitsubishi
# 4                                NaN                 american express
# ...                              ...                              ...
# 132007                           NaN                              NaN
# 132008                          6832                           cencar
# 132009                           NaN                              NaN
# 132010                           NaN                              NaN
# 132011                           NaN                   digital hearts
#
#         from_compustat  max_number_of_employees      max_turnover     _merge
# 0                  1.0                 221000.0    198270000000.0       both
# 1                  0.0                 434246.0    106916000000.0       both
# 2                  1.0                 484000.0    134134000000.0       both
# 3                  1.0                  86098.0  23103043000000.0       both
# 4                  1.0                 114352.0     55625000000.0       both
# ...                ...                      ...               ...        ...
# 132007             NaN                     <NA>              <NA>  left_only
# 132008             0.0                     <NA>      1067612799.0       both
# 132009             NaN                     <NA>              <NA>  left_only
# 132010             NaN                     <NA>              <NA>  left_only
# 132011             1.0                   1746.0     36517000000.0       both
#
# [132012 rows x 17 columns]

# %%
i=4
res.iloc[40*i:40*(i+1)]
# Out:
#                cleaned_name_x                 match_col            bvdid
# 160                  raytheon                  raytheon             8972  \
# 161                   newmont                   newmont             7881
# 162           daimlerchrysler           daimlerchrysler              NaN
# 163    saudi basic industries    saudi basic industries           248963
# 164                  borealis                  borealis           200460
# 165                     cppib                     cppib     HK0009135277
# 166           qatar petroleum           qatar petroleum              NaN
# 167        singapore airlines        singapore airlines           100713
# 168                       dsm                       dsm     CN9361219289
# 169                   sparton                   sparton             9922
# 170       mitsubishi electric       mitsubishi electric            19043
# 171                     paris                     paris            12156
# 172                    sprint                    sprint            10984
# 173    abu dhabi national oil    abu dhabi national oil           326213
# 174               astrazeneca               astrazeneca            28272
# 175             eastman kodak             eastman kodak             4194
# 176  citigroup global markets  citigroup global markets       GB01763297
# 177                      gail                      gail           213541
# 178           pratt & whitney           pratt & whitney  NZ9429036935208
# 179            sanofi-aventis            sanofi-aventis       GB03203829
# 180                   alcatel                   alcatel              NaN
# 181                     denso                     denso            19112
# 182                    repsol                    repsol            15319
# 183            france telecom            france telecom              NaN
# 184                      audi                      audi           101120
# 185                     nalco                     nalco           161797
# 186            newmont mining            newmont mining      AU099065997
# 187                    mouser                    mouser              NaN
# 188                    orange                    orange           220940
# 189                      hsbc                      hsbc       GB00617987
# 190                coal india                coal india           295778
# 191                bombardier                bombardier        CA20001NC
# 192                  euronext                  euronext           246498
# 193                first data                first data            25157
# 194        mouser electronics        mouser electronics     HK0006490233
# 195               honda motor               honda motor             5691
# 196               ge aviation               ge aviation     CN9366697570
# 197                   statoil                   statoil      AO100005282
# 198         ultra electronics         ultra electronics       GB02830397
# 199         texas instruments         texas instruments            10499
#
#                               name_internat
# 160                             RAYTHEON CO  \
# 161                            NEWMONT CORP
# 162                                     NaN
# 163             SAUDI BASIC INDUSTRIES CORP
# 164                                BOREALIS
# 165               Cppib (Hong Kong) Limited
# 166                                     NaN
# 167                  SINGAPORE AIRLINES LTD
# 168                     Dsm (china) limited
# 169                            SPARTON CORP
# 170                MITSUBISHI ELECTRIC CORP
# 171                              PARIS CORP
# 172                             SPRINT CORP
# 173                  ABU DHABI NATIONAL OIL
# 174                         ASTRAZENECA PLC
# 175                        EASTMAN KODAK CO
# 176        Citigroup Global Markets Limited
# 177                        GAIL (INDIA) LTD
# 178            Pratt & Whitney Holdings SAS
# 179      Sanofi-Aventis UK Holdings Limited
# 180                                     NaN
# 181                              DENSO CORP
# 182                               REPSOL SA
# 183                                     NaN
# 184                                 AUDI AG
# 185                        NALCO HOLDING CO
# 186              Newmont Mining Corporation
# 187                                     NaN
# 188                                  ORANGE
# 189                       Hsbc Holdings PLC
# 190                          COAL INDIA LTD
# 191                          Bombardier INC
# 192                             EURONEXT NV
# 193                         FIRST DATA CORP
# 194  Mouser Electronics (Hong Kong) Limited
# 195                      HONDA MOTOR CO LTD
# 196          Ge aviation (suzhou) co., ltd.
# 197                                 Statoil
# 198      Ultra Electronics Holdings Limited
# 199                   TEXAS INSTRUMENTS INC
#
#                             name_native    postcode                 city
# 160                                 NaN       02173            Lexington  \
# 161                                 NaN       80237               Denver
# 162                                 NaN         NaN                  NaN
# 163                                 NaN       11422               Riyadh
# 164                                 NaN        1020               Vienna
# 165           Cppib (Hong Kong) Limited
# 166                                 NaN         NaN                  NaN
# 167                                 NaN      819829            Singapore
# 168                         帝斯曼(中国)有限公司      200120             Shanghai
# 169                                 NaN       32130      De Leon Springs
# 170                                 NaN    100-8310                Tokyo
# 171                                 NaN       08060           Westampton
# 172                                 NaN       66251        Overland Park
# 173                                 NaN         NaN            Abu Dhabi
# 174                                 NaN     CB2 0AA            Cambridge
# 175                                 NaN       14650            Rochester
# 176    Citigroup Global Markets Limited     E14 5LB               London
# 177                                 NaN      110066            New Delhi
# 178        Pratt & Whitney Holdings SAS        8051             Harewood
# 179  Sanofi-Aventis UK Holdings Limited     RG6 1PT              Reading
# 180                                 NaN         NaN                  NaN
# 181                                 NaN    448-8661               Kariya
# 182                                 NaN       28045               Madrid
# 183                                 NaN         NaN                  NaN
# 184                                 NaN       85045           Ingolstadt
# 185                                 NaN  60563-1198           Naperville
# 186          Newmont Mining Corporation
# 187                                 NaN         NaN                  NaN
# 188                                 NaN       92449  Issy-les-Moulineaux
# 189                   Hsbc Holdings PLC     E14 5HQ               London
# 190                                 NaN      700156              Kolkata
# 191                      Bombardier INC     H3B 1Y8             Montreal
# 192                                 NaN     1012 JW            Amsterdam
# 193                                 NaN       30342              Atlanta
# 194                        貿澤電子(香港)有限公司
# 195                                 NaN    107-8556                Tokyo
# 196                      通用电气航空(苏州)有限公司      215021               Suzhou
# 197                             Statoil                           Luanda
# 198  Ultra Electronics Holdings Limited     W1H 6LR               London
# 199                                 NaN       75243               Dallas
#
#                               region_in_country country_iso_code
# 160                                         NaN              USA  \
# 161                                         NaN              USA
# 162                                         NaN              NaN
# 163                                         NaN              SAU
# 164                                         NaN              AUT
# 165                                                           HK
# 166                                         NaN              NaN
# 167                                         NaN              SGP
# 168                         East China|Shanghai               CN
# 169                                         NaN              USA
# 170                                         NaN              JPN
# 171                                         NaN              USA
# 172                                         NaN              USA
# 173                                         NaN              ARE
# 174                                         NaN              GBR
# 175                                         NaN              USA
# 176  England|London Inner|London (E)|London E14               GB
# 177                                         NaN              IND
# 178                                  Canterbury               NZ
# 179       England|Southern|Reading (RG)|Reading               GB
# 180                                         NaN              NaN
# 181                                         NaN              JPN
# 182                                         NaN              ESP
# 183                                         NaN              NaN
# 184                                         NaN              DEU
# 185                                         NaN              USA
# 186                                                           AU
# 187                                         NaN              NaN
# 188                                         NaN              FRA
# 189                                                           GB
# 190                                         NaN              IND
# 191                                      Quebec               CA
# 192                                         NaN              NLD
# 193                                         NaN              USA
# 194                                                           HK
# 195                                         NaN              JPN
# 196                          East China|Jiangsu               CN
# 197                                      Luanda               AO
# 198  England|London Inner|London (W)|London W1H               GB
# 199                                         NaN              USA
#
#                                        website_address ussic_primary_code
# 160                                                NaN             3812.0  \
# 161                                    www.newmont.com             1040.0
# 162                                                NaN                NaN
# 163                                      www.sabic.com             2860.0
# 164                              www.borealisgroup.com             2821.0
# 165                                      www.cppib.com               6726
# 166                                                NaN                NaN
# 167                               www.singaporeair.com             4512.0
# 168  www.dsm.com/countrysites/dsm-china/zh_cn/home....               7389
# 169                                    www.sparton.com             3679.0
# 170                         www.mitsubishielectric.com             3600.0
# 171                                  www.pariscorp.com             2761.0
# 172                                     www.sprint.com             4812.0
# 173                           www.adnocdistribution.ae             1311.0
# 174                                www.astrazeneca.com             2834.0
# 175                                      www.kodak.com             3861.0
# 176
# 177                                 www.gailonline.com             4922.0
# 178
# 179                                   www.sanofi.co.uk               6722
# 180                                                NaN                NaN
# 181                           www.denso.com/global/en/             3714.0
# 182                                     www.repsol.com             2911.0
# 183                                                NaN                NaN
# 184                                       www.audi.com             3711.0
# 185                                                NaN             2890.0
# 186
# 187                                                NaN                NaN
# 188                                     www.orange.com             4813.0
# 189                                       www.hsbc.com               6712
# 190                                   www.coalindia.in             1220.0
# 191                                 www.bombardier.com
# 192                                   www.euronext.com             6200.0
# 193                                  www.firstdata.com             7374.0
# 194                                      eu.mouser.com               5064
# 195                                    www.honda.co.jp             3711.0
# 196                                         www.ge.com               3728
# 197                                    www.statoil.com               1389
# 198                          www.ultra-electronics.com
# 199                                         www.ti.com             3674.0
#
#     nace_rev_2_core_code_4_digits            cleaned_name_y  from_compustat
# 160                           NaN                  raytheon             1.0  \
# 161                           NaN                   newmont             1.0
# 162                           NaN                       NaN             NaN
# 163                           NaN    saudi basic industries             1.0
# 164                           NaN                  borealis             1.0
# 165                                                   cppib             0.0
# 166                           NaN                       NaN             NaN
# 167                           NaN        singapore airlines             1.0
# 168                          7490                       dsm             0.0
# 169                           NaN                   sparton             1.0
# 170                           NaN       mitsubishi electric             1.0
# 171                           NaN                     paris             1.0
# 172                           NaN                    sprint             1.0
# 173                           NaN    abu dhabi national oil             1.0
# 174                           NaN               astrazeneca             1.0
# 175                           NaN             eastman kodak             1.0
# 176                                citigroup global markets             0.0
# 177                           NaN                      gail             1.0
# 178                                         pratt & whitney             0.0
# 179                                          sanofi-aventis             0.0
# 180                           NaN                       NaN             NaN
# 181                           NaN                     denso             1.0
# 182                           NaN                    repsol             1.0
# 183                           NaN                       NaN             NaN
# 184                           NaN                      audi             1.0
# 185                           NaN                     nalco             1.0
# 186                                          newmont mining             0.0
# 187                           NaN                       NaN             NaN
# 188                           NaN                    orange             1.0
# 189                          6420                      hsbc             0.0
# 190                           NaN                coal india             1.0
# 191                                              bombardier             0.0
# 192                           NaN                  euronext             1.0
# 193                           NaN                first data             1.0
# 194                          4652        mouser electronics             0.0
# 195                           NaN               honda motor             1.0
# 196                          3030               ge aviation             0.0
# 197                          0910                   statoil             0.0
# 198                                       ultra electronics             0.0
# 199                           NaN         texas instruments             1.0
#
#      max_number_of_employees      max_turnover     _merge
# 160                 119200.0     29176000000.0       both
# 161                  17100.0     12222000000.0       both
# 162                     <NA>              <NA>  left_only
# 163                  40000.0    198466764000.0       both
# 164                   7228.0     20418000000.0       both
# 165                    113.0          492000.0       both
# 166                     <NA>              <NA>  left_only
# 167                  31834.0     17774800000.0       both
# 168                    540.0       130597138.0       both
# 169                   3900.0       419362000.0       both
# 170                 149655.0   5003694000000.0       both
# 171                    300.0        64916000.0       both
# 172                  79900.0     41028000000.0       both
# 173                     <NA>     32111061000.0       both
# 174                  83500.0     44351000000.0       both
# 175                 145300.0     20183000000.0       both
# 176                   4385.0      5832000000.0       both
# 177                   4754.0   1456683000000.0       both
# 178                     <NA>       797565000.0       both
# 179                   4458.0      1271370626.0       both
# 180                     <NA>              <NA>  left_only
# 181                 171992.0   6401320000000.0       both
# 182                  46575.0   3127980000000.0       both
# 183                     <NA>              <NA>  left_only
# 184                  91674.0     61753000000.0       both
# 185                  12495.0      4250500000.0       both
# 186                    100.0       886500001.0       both
# 187                     <NA>              <NA>  left_only
# 188                 240145.0    178638000000.0       both
# 189                 330000.0     80283000000.0       both
# 190                 397138.0   1276274700000.0       both
# 191                  76400.0     20116000000.0       both
# 192                   2511.0      1442706000.0       both
# 193                  40000.0     12052000000.0       both
# 194                    113.0              <NA>       both
# 195                 219722.0  16907725000000.0       both
# 196                    400.0       130850149.0       both
# 197                   1200.0      3610000000.0       both
# 198                   4843.0      1245702039.0       both
# 199                  89875.0     20028000000.0       both

# %%
res.name_internat.notna().sum()
# Out:
# 80969

# %%
res[res.name_internat.isna()]
# Out:
#                               cleaned_name_x
# 20                                   gazprom  \
# 26                              saudi aramco
# 37                                  motorola
# 48                        board of directors
# 92                                      fiat
# ...                                      ...
# 132005                            spectrarep
# 132006    compania panamericana de servicios
# 132007  compania paraguaya de comunicaciones
# 132009                                 censu
# 132010                  bebidas del paraguay
#
#                                    match_col bvdid name_internat name_native
# 20                                   gazprom   NaN           NaN         NaN  \
# 26                              saudi aramco   NaN           NaN         NaN
# 37                                  motorola   NaN           NaN         NaN
# 48                        board of directors   NaN           NaN         NaN
# 92                                      fiat   NaN           NaN         NaN
# ...                                      ...   ...           ...         ...
# 132005                            spectrarep   NaN           NaN         NaN
# 132006    compania panamericana de servicios   NaN           NaN         NaN
# 132007  compania paraguaya de comunicaciones   NaN           NaN         NaN
# 132009                                 censu   NaN           NaN         NaN
# 132010                  bebidas del paraguay   NaN           NaN         NaN
#
#        postcode city region_in_country country_iso_code website_address
# 20          NaN  NaN               NaN              NaN             NaN  \
# 26          NaN  NaN               NaN              NaN             NaN
# 37          NaN  NaN               NaN              NaN             NaN
# 48          NaN  NaN               NaN              NaN             NaN
# 92          NaN  NaN               NaN              NaN             NaN
# ...         ...  ...               ...              ...             ...
# 132005      NaN  NaN               NaN              NaN             NaN
# 132006      NaN  NaN               NaN              NaN             NaN
# 132007      NaN  NaN               NaN              NaN             NaN
# 132009      NaN  NaN               NaN              NaN             NaN
# 132010      NaN  NaN               NaN              NaN             NaN
#
#        ussic_primary_code nace_rev_2_core_code_4_digits cleaned_name_y
# 20                    NaN                           NaN            NaN  \
# 26                    NaN                           NaN            NaN
# 37                    NaN                           NaN            NaN
# 48                    NaN                           NaN            NaN
# 92                    NaN                           NaN            NaN
# ...                   ...                           ...            ...
# 132005                NaN                           NaN            NaN
# 132006                NaN                           NaN            NaN
# 132007                NaN                           NaN            NaN
# 132009                NaN                           NaN            NaN
# 132010                NaN                           NaN            NaN
#
#         from_compustat  max_number_of_employees  max_turnover     _merge
# 20                 NaN                     <NA>          <NA>  left_only
# 26                 NaN                     <NA>          <NA>  left_only
# 37                 NaN                     <NA>          <NA>  left_only
# 48                 NaN                     <NA>          <NA>  left_only
# 92                 NaN                     <NA>          <NA>  left_only
# ...                ...                      ...           ...        ...
# 132005             NaN                     <NA>          <NA>  left_only
# 132006             NaN                     <NA>          <NA>  left_only
# 132007             NaN                     <NA>          <NA>  left_only
# 132009             NaN                     <NA>          <NA>  left_only
# 132010             NaN                     <NA>          <NA>  left_only
#
# [51043 rows x 17 columns]

# %%
## split df into batches and use multiprocessing to speed up the process
import numpy as np
import ray
from name_matching.name_matcher import NameMatcher
ray.init(ignore_reinit_error=True)


matcher = NameMatcher(low_memory=False, top_n=5, common_words=False, legal_suffixes=True,
                      distance_metrics=['editex', 'discounted_levenshtein',
                                        'refined_soundex'])
matcher.load_and_process_master_data(df_matching_data=df_static.head(500000),
                                         column='cleaned_name')

ref_matcher = ray.put(matcher)

def split_df(df, chunk_size):
    num_chunks = len(df) // chunk_size + 1
    return np.array_split(df, num_chunks)

@ray.remote
def match_names(df_matching, column_matching, matcher):
    res = matcher.match_names(to_be_matched=df_matching, column_matching=column_matching)
    matches = res[res['score'] > 95]
    return matches

def match_names_multiprocessing(df_matching, column_matching, matcher, chunk_size=1000):
    df_batches = split_df(df_matching, chunk_size)
    futures = [match_names.remote(df, column_matching, matcher) for df in df_batches]
    matches = ray.get(futures)
    return pd.concat(matches)

matches = match_names_multiprocessing(res[res.name_internat.isna()], 'cleaned_name_x', ref_matcher)
# Out:
# 2023-07-21 01:53:10,429	INFO worker.py:1474 -- Calling ray.init() again after it has already been called.
# /home/ec2-user/anaconda3/envs/python3/lib/python3.10/site-packages/sklearn/feature_extraction/text.py:1682: RuntimeWarning: divide by zero encountered in true_divide
#   idf = np.log(n_samples / df) + 1

# %%
matches
# Out:
#                                  original_name
# 1116                                       lmt  \
# 1482                      cargill incorporated
# 1811                                        rr
# 2470                               statoil asa
# 3888    caisse de depot et placement du quebec
# ...                                        ...
# 131617                              serene spa
# 131723                                 stearns
# 131770                          komercni banka
# 131805                       l3 communications
# 131837                                bilstein
#
#                                        match_name       score  match_index
# 1116                                          lmt  100.000000     146450.0
# 1482                                      cargill  100.000000     111882.0
# 1811                                           rr  100.000000     117173.0
# 2470                                      statoil  100.000000     192117.0
# 3888    caisse de depot et de placement du quebec   95.058981     175757.0
# ...                                           ...         ...          ...
# 131617                                     serene  100.000000     388705.0
# 131723                                    stearns  100.000000     289040.0
# 131770                          komercni banka as  100.000000       4925.0
# 131805                          l3 communications  100.000000     159634.0
# 131837                                   bilstein  100.000000     258888.0
#
# [474 rows x 4 columns]

# %%
res_fuzzy = matches[['original_name', 'match_name']].merge(df_static, left_on='match_name', right_on='cleaned_name')
res_fuzzy.rename(columns={'original_name': 'cleaned_name_x', 'match_name': 'cleaned_name_y'}, inplace=True)
res_fuzzy
# Out:
#                              cleaned_name_x
# 0                                       lmt  \
# 1                      cargill incorporated
# 2                                        rr
# 3                               statoil asa
# 4    caisse de depot et placement du quebec
# ..                                      ...
# 487                              serene spa
# 488                                 stearns
# 489                          komercni banka
# 490                       l3 communications
# 491                                bilstein
#
#                                 cleaned_name_y          bvdid
# 0                                          lmt   DE7370062061  \
# 1                                      cargill     GB01387437
# 2                                           rr     NL67275974
# 3                                      statoil    AO100005282
# 4    caisse de depot et de placement du quebec     CAFEB21716
# ..                                         ...            ...
# 487                                     serene     GB03024917
# 488                                    stearns  US113407022GN
# 489                          komercni banka as         204719
# 490                          l3 communications   DE2050486935
# 491                                   bilstein   DE4190003651
#
#                                  name_internat
# 0                            LMT GmbH & Co. KG  \
# 1                                  Cargill PLC
# 2                              RR Holding B.V.
# 3                                      Statoil
# 4    Caisse de depot et de placement du Quebec
# ..                                         ...
# 487                       Serene Group Limited
# 488                                    Stearns
# 489                          KOMERCNI BANKA AS
# 490            L-3 Communications Holding GmbH
# 491                     BILSTEIN GmbH & Co. KG
#
#                                    name_native    postcode          city
# 0                            LMT GmbH & Co. KG       21493  Schwarzenbek  \
# 1                                  Cargill PLC    KT13 0SL     Weybridge
# 2                              RR Holding B.V.     6546 BE      Nijmegen
# 3                                      Statoil                    Luanda
# 4    Caisse de depot et de placement du Quebec  QC G1R 3X5        Quebec
# ..                                         ...         ...           ...
# 487                       Serene Group Limited    EC1V 4PY        London
# 488                                    Stearns  90807-2910    Long Beach
# 489                                        NaN      114 07        Prague
# 490            L-3 Communications Holding GmbH       72793    Pfullingen
# 491                     BILSTEIN GmbH & Co. KG       58119         Hagen
#
#                                      region_in_country country_iso_code
# 0                         Schleswig-Holstein|Lauenburg               DE  \
# 1    England|London Outer|Kingston Upon Thames (KT)...               GB
# 2                                  Gelderland|Nijmegen               NL
# 3                                               Luanda               AO
# 4                                                                    CA
# ..                                                 ...              ...
# 487       England|London Inner|London (EC)|London EC1V               GB
# 488                      California|Los Angeles County               US
# 489                                                NaN              CZE
# 490            Baden-Wuerttemberg|Tuebingen|Reutlingen               DE
# 491                 Nordrhein-Westfalen|Arnsberg|Hagen               DE
#
#                 website_address ussic_primary_code
# 0             www.lmt-tools.com               6722  \
# 1             www.cargill.co.uk
# 2    www.directezorgnijmegen.nl               6719
# 3               www.statoil.com               1389
# 4                  www.cdpq.com
# ..                          ...                ...
# 487
# 488          www.stearnsnet.com               5411
# 489                   www.kb.cz             6020.0
# 490              www.l-3com.com               6722
# 491    www.bilstein-kaltband.de               3312
#
#     nace_rev_2_core_code_4_digits                               cleaned_name
# 0                                                                        lmt  \
# 1                                                                    cargill
# 2                                                                         rr
# 3                            0910                                    statoil
# 4                                  caisse de depot et de placement du quebec
# ..                            ...                                        ...
# 487                                                                   serene
# 488                          4711                                    stearns
# 489                           NaN                          komercni banka as
# 490                                                        l3 communications
# 491                          2410                                   bilstein
#
#      from_compustat  max_number_of_employees    max_turnover
# 0               0.0                   2148.0     495455238.0  \
# 1               0.0                   6076.0    2825848430.0
# 2               0.0                   4759.0            <NA>
# 3               0.0                   1200.0    3610000000.0
# 4               0.0                   1454.0   38435288684.0
# ..              ...                      ...             ...
# 487             0.0                    472.0       8203010.0
# 488             0.0                    696.0        382000.0
# 489             1.0                  14843.0  103479000000.0
# 490             0.0                   1775.0     527987497.0
# 491             0.0                    782.0     636416277.0
#
#                                      match_col
# 0                                       lmt  &
# 1                                      cargill
# 2                                           rr
# 3                                      statoil
# 4    caisse de depot et de placement du quebec
# ..                                         ...
# 487                                     serene
# 488                                    stearns
# 489                          komercni banka as
# 490                         l-3 communications
# 491                                bilstein  &
#
# [492 rows x 17 columns]

# %%
res_full = pd.concat([res[res.name_internat.notna()], res_fuzzy])
res_full.drop(columns=['match_col', 'cleaned_name_y', '_merge', 'cleaned_name'], inplace=True)
res_full.rename(columns={'cleaned_name_x': 'cleaned_name'}, inplace=True)
res_full
# Out:
#                         cleaned_name          bvdid
# 0                          microsoft          12141  \
# 1    international business machines    US130871985
# 2                            siemens          19349
# 3                         mitsubishi         100555
# 4                   american express           1447
# ..                               ...            ...
# 487                       serene spa     GB03024917
# 488                          stearns  US113407022GN
# 489                   komercni banka         204719
# 490                l3 communications   DE2050486935
# 491                         bilstein   DE4190003651
#
#                             name_internat
# 0                          MICROSOFT CORP  \
# 1    International Business Machines Corp
# 2                              SIEMENS AG
# 3                         MITSUBISHI CORP
# 4                     AMERICAN EXPRESS CO
# ..                                    ...
# 487                  Serene Group Limited
# 488                               Stearns
# 489                     KOMERCNI BANKA AS
# 490       L-3 Communications Holding GmbH
# 491                BILSTEIN GmbH & Co. KG
#
#                               name_native    postcode        city
# 0                                     NaN  98052-6399     Redmond  \
# 1    International Business Machines Corp       10504      Armonk
# 2                                     NaN       80333      Munich
# 3                                     NaN    100-8086       Tokyo
# 4                                     NaN       10285    New York
# ..                                    ...         ...         ...
# 487                  Serene Group Limited    EC1V 4PY      London
# 488                               Stearns  90807-2910  Long Beach
# 489                                   NaN      114 07      Prague
# 490       L-3 Communications Holding GmbH       72793  Pfullingen
# 491                BILSTEIN GmbH & Co. KG       58119       Hagen
#
#                                 region_in_country country_iso_code
# 0                                             NaN              USA  \
# 1                                        New York               US
# 2                                             NaN              DEU
# 3                                             NaN              JPN
# 4                                             NaN              USA
# ..                                            ...              ...
# 487  England|London Inner|London (EC)|London EC1V               GB
# 488                 California|Los Angeles County               US
# 489                                           NaN              CZE
# 490       Baden-Wuerttemberg|Tuebingen|Reutlingen               DE
# 491            Nordrhein-Westfalen|Arnsberg|Hagen               DE
#
#               website_address ussic_primary_code
# 0           www.microsoft.com             7372.0  \
# 1                 www.ibm.com
# 2             www.siemens.com             9997.0
# 3      www.mitsubishicorp.com             5099.0
# 4     www.americanexpress.com             6141.0
# ..                        ...                ...
# 487
# 488        www.stearnsnet.com               5411
# 489                 www.kb.cz             6020.0
# 490            www.l-3com.com               6722
# 491  www.bilstein-kaltband.de               3312
#
#     nace_rev_2_core_code_4_digits  from_compustat  max_number_of_employees
# 0                             NaN             1.0                 221000.0  \
# 1                                             0.0                 434246.0
# 2                             NaN             1.0                 484000.0
# 3                             NaN             1.0                  86098.0
# 4                             NaN             1.0                 114352.0
# ..                            ...             ...                      ...
# 487                                           0.0                    472.0
# 488                          4711             0.0                    696.0
# 489                           NaN             1.0                  14843.0
# 490                                           0.0                   1775.0
# 491                          2410             0.0                    782.0
#
#          max_turnover
# 0      198270000000.0
# 1      106916000000.0
# 2      134134000000.0
# 3    23103043000000.0
# 4       55625000000.0
# ..                ...
# 487         8203010.0
# 488          382000.0
# 489    103479000000.0
# 490       527987497.0
# 491       636416277.0
#
# [81461 rows x 14 columns]

# %%
res_full.to_pickle('matching_result_lexis_orbis2023_compustat.pkl')

# %%
df_dynamic[df_dynamic.bvdid.isin(res_full.bvdid)].to_pickle('matching_result_dynamic_lexis_orbis2023_compustat.pkl')

# %%
# matches.to_pickle('dnb_matches1.pkl')

# %%
# matches = pd.read_pickle('dnb_matches.pkl')

# %%
# res.to_pickle('res1.pkl')

# %%
names_ids = lexis_firm_names_clean[['cleaned_name']].merge(res_full[['cleaned_name', 'bvdid']],
                                         on='cleaned_name', how='inner')
names_ids = names_ids.dropna().set_index('cleaned_name').squeeze().to_dict()

# %%
important_labels = ['StrategicAlliance', 'JointVenture', 'Marketing', 'Manufacturing',
                    'ResearchandDevelopment', 'Licensing']

# read lexis nexis articles with detected orgs and relations
df = pd.read_pickle('/Users/Jakob/Documents/financial_news_data/lexisnexis_preds_robust_vortex_99.pkl')

df.drop(columns=['index_x', 'index_y'], inplace=True)


df = df[['publication', 'publication_date', 'firms', 'rels_pred', 'country', 'industry']]

df['cleaned_firms'] = df.firms.apply(lambda firms: [firm_name_clean(firm) for firm in firms])


names_ids = lexis_firm_names_clean.merge(res_full[['cleaned_name', 'bvdid']],
                                         on='cleaned_name', how='left')

rels = df[['publication_date', 'cleaned_firms', 'rels_pred']].copy()
rels['firm_a'] = rels.cleaned_firms.str[0]
rels['firm_b'] = rels.cleaned_firms.str[1]
rels.drop(columns=['cleaned_firms'], inplace=True)

rels['firm_a'] = rels.firm_a.map(names_ids)
rels['firm_b'] = rels.firm_b.map(names_ids)

rels.dropna(inplace=True)

# remove terminated
rels = rels[rels.rels_pred.apply(lambda rels: 'Terminated' not in rels)]

# remove firms where both participants are the same
rels = rels[rels.firm_a != rels.firm_b]

# remove duplicate relationships (same participants, same type, same year)
rels['year'] = rels.publication_date.dt.year
rels = rels.groupby(['firm_a', 'firm_b', 'year']).agg(list)
rels.reset_index(inplace=True)

# from itertools import chain
# rels['rels_pred'] = rels.rels_pred.apply(chain.from_iterable).apply(list).apply(set).apply(list)

rels = rels.explode('rels_pred')

orbis.to_csv(os.path.join(output_path, 'rel_database', 'lexis_orbis_match.csv'), index=False)

# save separate csvs for each relation type
for rel_name in important_labels:
    rels[rels.rels_pred.apply(lambda rel: rel==rel_name)].drop(columns=['rels_pred']).to_csv(
            os.path.join(output_path, 'rel_database', f'{rel_name}_LexisNexis.csv'), index=False)

# %%
merged_orbis = merged.merge(df_static, left_on='matched_name', right_on='cleaned_name', how='inner')
merged_orbis = merged_orbis.drop(columns=['index'])
merged_orbis
# Out:
#                          original_name                     matched_name
# 0                            microsoft                        microsoft  \
# 1      international business machines  international business machines
# 2                              siemens                          siemens
# 3                           mitsubishi                       mitsubishi
# 4                     american express                 american express
# ...                                ...                              ...
# 78212                        objectiva                        objective
# 78213                            k-air                             kair
# 78214                              f&h                               fh
# 78215                      software602                   software602 as
# 78216                 cumulus networks                  cumulus network
#
#                  bvdid                         name_internat
# 0          US911144442                 Microsoft Corporation  \
# 1          US130871985  International Business Machines Corp
# 2         DE2010000581                            Siemens AG
# 3      JP5010001008771                Mitsubishi Corporation
# 4          US134922250              American Express Company
# ...                ...                                   ...
# 78212      AU050539350         Objective Corporation Limited
# 78213       RU60611419                                  Kair
# 78214     US189804411L                             FH CO INC
# 78215       CZ63078236                      Software602 a.s.
# 78216     US250864175L                   Cumulus Network INC
#
#                                 name_native    postcode           city
# 0                     Microsoft Corporation       98052        Redmond  \
# 1      International Business Machines Corp       10504         Armonk
# 2                                Siemens AG       80333        Munchen
# 3                                  三菱商事株式会社    100-0005     Chiyoda-Ku
# 4                  American Express Company       10285       New York
# ...                                     ...         ...            ...
# 78212         Objective Corporation Limited        2060   North Sydney
# 78213                                  Каир      610046          Kirov
# 78214                             FH CO INC  67067-9001          Kechi
# 78215                      Software602 a.s.       14000        Praha 4
# 78216                   Cumulus Network INC  94041-2055  Mountain View
#
#                                      region_in_country country_iso_code
# 0                                           Washington               US  \
# 1                                             New York               US
# 2                                                                    DE
# 3                                          Kanto|Tokyo               JP
# 4                                             New York               US
# ...                                                ...              ...
# 78212                                  New South Wales               AU
# 78213                Volga federal region|Kirov region               RU
# 78214                           Kansas|Sedgwick County               US
# 78215  Prague - capital of the CR|District of Prague 4               CZ
# 78216                    California|Santa Clara County               US
#
#                               website_address ussic_primary_code
# 0                           www.microsoft.com                     \
# 1                                 www.ibm.com
# 2                             www.siemens.com
# 3                      www.mitsubishicorp.com
# 4                     www.americanexpress.com
# ...                                       ...                ...
# 78212                       www.objective.com               7371
# 78213
# 78214  www.f-hcompanies_pristine_pristine.com               1743
# 78215                              www.602.cz
# 78216
#
#       nace_rev_2_core_code_4_digits                     cleaned_name
# 0                                                          microsoft  \
# 1                                    international business machines
# 2                                                            siemens
# 3                                                         mitsubishi
# 4                                                   american express
# ...                             ...                              ...
# 78212                          6201                        objective
# 78213                                                           kair
# 78214                          4399                               fh
# 78215                                                 software602 as
# 78216                                                cumulus network
#
#        max_number_of_employees  max_turnover
# 0                       221000  198270000000
# 1                       434246  106916000000
# 2                       477100  113278278484
# 3                        86098  195485450403
# 4                        64611   43645000000
# ...                        ...           ...
# 78212                      240      73276251
# 78213                       35      45984051
# 78214                      130        500000
# 78215                      110      10435134
# 78216                      130      51900000
#
# [78217 rows x 15 columns]

# %%
df_dynamic[df_dynamic.bvdid.isin(merged_orbis.bvdid)]
# Out:
#                  bvdid  closing_date  number_of_employees
# 73        AE0000000904      20141231                  195  \
# 74        AE0000000904      20201231                  195
# 76        AE0000001238      20130331                   25
# 77        AE0000001238      20140331                   25
# 78        AE0000001238      20150331                   25
# ...                ...           ...                  ...
# 19421185    ZWFEB23823      20171231                  823
# 19421186    ZWFEB23823      20181231                 <NA>
# 19421187    ZWFEB23823      20191231                 <NA>
# 19421188    ZWFEB23823      20201231                   25
# 19421189    ZWFEB23823      20211231                  565
#
#           operating_revenue_turnover  total_assets  added_value
# 73                         220000000           NaN          NaN  \
# 74                         220000000           NaN          NaN
# 76                          78869679           NaN          NaN
# 77                          73534249           NaN          NaN
# 78                          54949375           NaN          NaN
# ...                              ...           ...          ...
# 19421185                    89420000           NaN          NaN
# 19421186                   120394000           NaN          NaN
# 19421187                   383836371           NaN          NaN
# 19421188                    20295000           NaN          NaN
# 19421189                   153800539           NaN          NaN
#
#           research_and_development_expenses
# 73                                      NaN
# 74                                      NaN
# 76                                      NaN
# 77                                      NaN
# 78                                      NaN
# ...                                     ...
# 19421185                                NaN
# 19421186                                NaN
# 19421187                                NaN
# 19421188                                NaN
# 19421189                                NaN
#
# [635268 rows x 7 columns]
